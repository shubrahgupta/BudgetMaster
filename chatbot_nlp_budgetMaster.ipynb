# %% [markdown]
# <a href="https://colab.research.google.com/github/shubrahgupta/BudgetMaster/blob/main/chatbot_nlp_budgetMaster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
ourData = {"ourIntents": [

             {"tag": "gibberish",
              "patterns": ["hello", "hi", "bye", " whats up", "fuck you","what's your name?", "who are you?", "how are you doing"],
              "responses": ["Use proper terms such as expense/income/received"]
             },

             {"tag": "income",
              "patterns": ["received income", "company paid me", "got my salary", "received salary", "income arrived", "income","salary", "earned","earns"],
              "responses": ["Categorising as income"]
             },
             {"tag": "expense",
              "patterns": [ "spent", "purchase", "purchased on", "spent on", "spent for", "lost money", "expense", "lost", "burnt money", "burnt"],
              "responses": ["Categorising as expense"]
             },
            {"tag": "received",
              "patterns": [ "received", "got as gift", "gift"],
              "responses": ["Categorising as extra received"]
             },


]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
import tensorflow as tf
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               4480
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_14 (Dense)            (None, 4)                 260
#
# =================================================================
# Total params: 12,996
# Trainable params: 12,996
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 582ms/step - loss: 1.3822 - accuracy: 0.2000
# Epoch 2/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3055 - accuracy: 0.4800
# Epoch 3/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.1545 - accuracy: 0.7200
# Epoch 4/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0591 - accuracy: 0.8400
# Epoch 5/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.9849 - accuracy: 0.7600
# Epoch 6/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8962 - accuracy: 0.8000
# Epoch 7/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7622 - accuracy: 0.8000
# Epoch 8/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6937 - accuracy: 0.8000
# Epoch 9/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5249 - accuracy: 0.8400
# Epoch 10/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4639 - accuracy: 0.9200
# Epoch 11/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.3559 - accuracy: 0.9200
# Epoch 12/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3619 - accuracy: 0.8800
# Epoch 13/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3012 - accuracy: 0.9600
# Epoch 14/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1556 - accuracy: 1.0000
# Epoch 15/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1580 - accuracy: 0.9600
# Epoch 16/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1406 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1139 - accuracy: 0.9600
# Epoch 18/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1318 - accuracy: 0.9600
# Epoch 19/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0625 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0638 - accuracy: 0.9600
# Epoch 24/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6718e-04 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.4997e-05 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.0360e-04 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.4243e-05 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.0702e-04 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.5490e-04 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2956e-04 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.0885e-04 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.7643e-04 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8855e-05 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.6165e-04 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7996e-04 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.7070e-04 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7255e-04 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2029e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1568e-04 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3659e-04 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9898e-04 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 16ms/step - loss: 2.7622e-04 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2050e-04 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4175e-04 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.1559e-04 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9819e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2412e-05 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.8110e-05 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 13ms/step - loss: 9.0292e-04 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3670e-04 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.6453e-05 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.1050e-05 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.3323e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8455e-04 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8051e-06 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.9111e-05 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 14ms/step - loss: 2.8659e-05 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.9820e-05 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2720e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2812e-04 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4705e-05 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.8810e-05 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8199e-04 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.2773e-04 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4236e-04 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8791e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1902e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7795e-05 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8433e-06 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1096e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6205e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4187e-04 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3763e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1796e-05 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 13ms/step - loss: 2.2548e-05 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2932e-05 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.8210e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.6803e-06 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.5641e-05 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0804e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8543e-04 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0631e-05 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3628e-04 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8159e-05 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1787e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.7917e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1816e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.3761e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9230e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.7702e-05 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 11ms/step - loss: 9.6529e-05 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5668e-05 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2100e-05 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.8649e-05 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4432e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.4345e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6784e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 17ms/step - loss: 4.5242e-05 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.1139e-04 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.5658e-05 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.8757e-04 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2723e-06 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8651e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3223e-04 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5646e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.2024e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.2329e-06 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2006e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.3372e-04 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8412e-05 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0039e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8948e-05 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.5970e-05 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.1433e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2539e-05 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.9410e-04 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0633e-05 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7576e-06 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6039e-05 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.4247e-05 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6189e-04 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.8434e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.5260e-05 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.0671e-05 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5323e-05 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.9996e-04 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.0917e-06 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1016e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.4890e-06 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.5280e-05 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.1038e-05 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 20ms/step - loss: 4.9457e-05 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2104e-04 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8642e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1138e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.4789e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8548e-05 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0728e-05 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.3062e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5041e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.8772e-05 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7778e-06 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4365e-05 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.7040e-06 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.2724e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5275e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 11ms/step - loss: 9.8891e-06 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.7244e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.4279e-05 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5208e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.9465e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.5854e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 10ms/step - loss: 9.8310e-05 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7231e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8924e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0549e-04 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["ourIntents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
flag = True
while flag:
  
    newMessage = input("")
    if ("stop" in newMessage) | ("end" in newMessage) | ("exit" in newMessage):
      flag = False
      break
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# received income today
# 1/1 [==============================] - 0s 24ms/step
# Categorising as income
# exit

# %%
sent = "please stop"
sent1 = "stop now"
sent2 = "can you stop?"
sent3 = "stop"
sent4 = "           "
sent5 = " do nothing"
arr = [sent,sent1,sent2,sent3, sent4, sent5]
for i in range(len(arr)):
  if "stop" in arr[i]: 
    print("true")
  else:
    print("false")
# Out:
# true
# true
# true
# true
# false
# false
