# %% [markdown]
# <a href="https://colab.research.google.com/github/shubrahgupta/BudgetMaster/blob/main/chatbot_nlp_budgetMaster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import string
import random
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
ourData = {"ourIntents": [

             {"tag": "gibberish",
              "patterns": ["hello", "hi", "bye", " whats up", "fuck you","what's your name?", "who are you?",
                           "how are you doing", "' '", ",", "! @ # $ ^ % & * ( ) - _ = + / . ? > < : ;"],
              "responses": ["Use proper terms such as expense/income/received"]
             },

             {"tag": "income",
              "patterns": ["received income", "company paid me", "got my salary", "received salary", "income arrived", "income","salary", "earned","earns"],
              "responses": ["Categorising as income"]
             },
             {"tag": "expense",
              "patterns": [ "spent", "purchase", "purchased on", "spent on", "spent for", "lost money", "expense", "lost", "burnt money", "burnt"],
              "responses": ["Categorising as expense"]
             },
            {"tag": "received",
              "patterns": [ "received", "got as gift", "gift", "cashback", "got"],
              "responses": ["Categorising as extra received"]
             },


]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
import tensorflow as tf
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tf.keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               4992
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 13,508
# Trainable params: 13,508
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 2/2 [==============================] - 1s 12ms/step - loss: 1.3895 - accuracy: 0.1714
# Epoch 2/200
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2601 - accuracy: 0.5143
# Epoch 3/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.1084 - accuracy: 0.6857
# Epoch 4/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9708 - accuracy: 0.8000
# Epoch 5/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8198 - accuracy: 0.8286
# Epoch 6/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6799 - accuracy: 0.9143
# Epoch 7/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6709 - accuracy: 0.8857
# Epoch 8/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4675 - accuracy: 0.8571
# Epoch 9/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4435 - accuracy: 0.8857
# Epoch 10/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3754 - accuracy: 0.9143
# Epoch 11/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3328 - accuracy: 0.9714
# Epoch 12/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1961 - accuracy: 1.0000
# Epoch 13/200
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1292 - accuracy: 0.9714
# Epoch 14/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0979 - accuracy: 1.0000
# Epoch 15/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0907 - accuracy: 1.0000
# Epoch 16/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1188 - accuracy: 0.9714
# Epoch 17/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0870 - accuracy: 1.0000
# Epoch 18/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 19/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2143 - accuracy: 0.9143
# Epoch 20/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0574 - accuracy: 1.0000
# Epoch 21/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 22/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 23/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 24/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 25/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 26/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 27/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0602 - accuracy: 0.9714
# Epoch 28/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 29/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 30/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 31/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 32/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 33/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 34/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 35/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 36/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 37/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 38/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 39/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 40/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 41/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 42/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 43/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 44/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 45/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 46/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 47/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 48/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 49/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 50/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 51/200
# 2/2 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 52/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 53/200
# 2/2 [==============================] - 0s 7ms/step - loss: 3.2333e-04 - accuracy: 1.0000
# Epoch 54/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 55/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 56/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 57/200
# 2/2 [==============================] - 0s 10ms/step - loss: 6.3217e-04 - accuracy: 1.0000
# Epoch 58/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 59/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 60/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 61/200
# 2/2 [==============================] - 0s 12ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 62/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 63/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0263 - accuracy: 0.9714
# Epoch 64/200
# 2/2 [==============================] - 0s 12ms/step - loss: 8.7454e-04 - accuracy: 1.0000
# Epoch 65/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 66/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 67/200
# 2/2 [==============================] - 0s 11ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 68/200
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 69/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 70/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 71/200
# 2/2 [==============================] - 0s 9ms/step - loss: 6.5981e-04 - accuracy: 1.0000
# Epoch 72/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 73/200
# 2/2 [==============================] - 0s 8ms/step - loss: 8.0355e-04 - accuracy: 1.0000
# Epoch 74/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch
200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 189/200
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2162e-04 - accuracy: 1.0000
# Epoch 190/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 191/200
# 2/2 [==============================] - 0s 8ms/step - loss: 7.4459e-04 - accuracy: 1.0000
# Epoch 192/200
# 2/2 [==============================] - 0s 8ms/step - loss: 4.7544e-04 - accuracy: 1.0000
# Epoch 193/200
# 2/2 [==============================] - 0s 8ms/step - loss: 4.0260e-04 - accuracy: 1.0000
# Epoch 194/200
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 195/200
# 2/2 [==============================] - 0s 9ms/step - loss: 1.4852e-04 - accuracy: 1.0000
# Epoch 196/200
# 2/2 [==============================] - 0s 8ms/step - loss: 3.3698e-05 - accuracy: 1.0000
# Epoch 197/200
# 2/2 [==============================] - 0s 8ms/step - loss: 5.4467e-04 - accuracy: 1.0000
# Epoch 198/200
# 2/2 [==============================] - 0s 9ms/step - loss: 3.3360e-04 - accuracy: 1.0000
# Epoch 199/200
# 2/2 [==============================] - 0s 8ms/step - loss: 2.7869e-04 - accuracy: 1.0000
# Epoch 200/200
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000

# %%
def ourText(text):
  newtkns = nltk.word_tokenize(text)
  newtkns = [lm.lemmatize(word) for word in newtkns]
  return newtkns

def wordBag(text, vocab):
  newtkns = ourText(text)
  bagOwords = [0] * len(vocab)
  for w in newtkns:
    for idx, word in enumerate(vocab):
      if word == w:
        bagOwords[idx] = 1
  return num.array(bagOwords)

def Pclass(text, vocab, labels):
  bagOwords = wordBag(text, vocab)
  ourResult = ourNewModel.predict(num.array([bagOwords]))[0]
  newThresh = 0.2
  yp = [[idx, res] for idx, res in enumerate(ourResult) if res > newThresh]

  yp.sort(key=lambda x: x[1], reverse=True)
  newList = []
  for r in yp:
    newList.append(labels[r[0]])
  return newList

def getRes(firstlist, fJson):
  tag = firstlist[0]
  listOfIntents = fJson["ourIntents"]
  for i in listOfIntents:
    if i["tag"] == tag:
      ourResult = random.choice(i["responses"])
      break
  return ourResult

# %%
flag = True
while flag:
  
    newMessage = input("")
    if ("stop" in newMessage) | ("end" in newMessage) | ("exit" in newMessage):
      flag = False
      break
    intents = Pclass(newMessage, newWords, ourClasses)
    ourResult = getRes(intents, ourData)
    print(ourResult)
# Out:
# got 66
# 1/1 [==============================] - 0s 94ms/step
# Categorising as extra received
# earned 55
# 1/1 [==============================] - 0s 23ms/step
# Categorising as income
# cashback of 50
# 1/1 [==============================] - 0s 22ms/step
# Categorising as extra received
# exit

# %%
model_json = ourNewModel.to_json()
with open("budgetMaster_chatbot.json", "w") as json_file:
    json_file.write(model_json)

ourNewModel.save("budgetMaster_chatbot.h5")

# %%
sent = "please stop"
sent1 = "stop now"
sent2 = "can you stop?"
sent3 = "stop"
sent4 = "           "
sent5 = " do nothing"
arr = [sent,sent1,sent2,sent3, sent4, sent5]
for i in range(len(arr)):
  if "stop" in arr[i]: 
    print("true")
  else:
    print("false")
# Out:
# true
# true
# true
# true
# false
# false
